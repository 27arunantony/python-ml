# %% [markdown]
# ## POS tagging using modified Viterbi

# %% [markdown]
# ### Data Preparation

# %%
#Importing libraries
import nltk
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from collections import Counter
import time
from nltk.tokenize import word_tokenize
from functools import reduce
import random
import pdb
import re

# %%
# Reading Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
# splitting Treebank dataset into train & validation set in ration of 95:5 %
train_set, validation_set = train_test_split(nltk_data,train_size=.95,test_size=0.05,random_state=70)

# %%
print("Dataset size-> nltk: {}, Training:{}, Validation: {}".format(len(nltk_data),len(train_set),len(validation_set)))
# Out:
# Dataset size-> nltk: 3914, Training:3718, Validation: 196

# %%
tagged_train_set=[tup for set in train_set for tup in set]
# Extracging vocabulary and respective Tags sperately
vocabulary=(set([v[0] for v in tagged_train_set]))
tags=set(v[1] for v in tagged_train_set)
print("Length-> Vocabulary: {}, Tags: {}".format(len(vocabulary),len(tags)))
print("Available Tags-> ",tags)
# Out:
# Length-> Vocabulary: 12088, Tags: 12
# Available Tags->  {'ADV', 'CONJ', 'PRON', 'ADJ', 'NUM', 'PRT', 'NOUN', '.', 'DET', 'VERB', 'ADP', 'X'}

# %% [markdown]
# ### Build the vanilla Viterbi based POS tagger

# %%
# compute word given tag: Emission Probability
def word_given_tag(word, tag, train_bag = tagged_train_set):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# %%
def t2_given_t1(t2, t1, train_bag = tagged_train_set):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
tags_matrix = np.zeros((len(tags), len(tags)), dtype='float32')
for i, t1 in enumerate(list(tags)):
    for j, t2 in enumerate(list(tags)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

# %%
# tags_matrix data Frame
tags_df = pd.DataFrame(tags_matrix, columns = list(tags), index=list(tags))

# %%
tags_df.loc['.', :]
# Out:
# ADV     0.053345
# CONJ    0.058015
# PRON    0.065469
# ADJ     0.043197
# NUM     0.081275
# PRT     0.002515
# NOUN    0.222452
# .       0.091783
# DET     0.173507
# VERB    0.089807
# ADP     0.091334
# X       0.027211
# Name: ., dtype: float32

# %%
def Viterbi(words, train_bag = tagged_train_set,backoff=[]):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        e=[]
        t=[]
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]

            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            t.append(transition_p)
            e.append(emission_p) #Adding Emission prbability for all tag
            state_probability = emission_p * transition_p    
            p.append(state_probability)
        pmax = max(p)
        state_max = None
        if pmax==0.0:
            linker=backoff.copy()
            while linker!=[]:
                if state_max==None:
                    state_max=linker.pop()([word])[0][1]
                else:
                    linker.clear()
            if state_max==None and backoff!=[]:
                if sum(e)==0.0:
                    state_max = T[t.index(max(t))]
        # getting state for which probability is maximum
        if state_max==None:
            state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
validation_run_base=[tup for sent in validation_set for tup in sent] # it's a list of tuple with WORD and TAG

validation_tagged_words = [tup[0] for sent in validation_set for tup in sent] # list of words only

# %%
#Validation set (word,tag)
tagged_words_validation=[tup for ls in validation_set for tup in ls]

#Validation set words
vocabulary_validation=set([t[0] for t in tagged_words_validation])
print("-"*100)
print("Total unique vocab")
print("Training set->{} Validation set->{}\n".format(str(len(vocabulary)),str(len(vocabulary_validation))))

#Unknown words
print("-"*100)
print("Vocabulary only in Validation Set (not in Training set)")
UnknownWords=list(vocabulary_validation-vocabulary)
print("Total Unknown words: {}, sample->{}\n".format(len(UnknownWords),UnknownWords[0:3]))

#Common Vocabulary
print("-"*100)
CommonWords=list(vocabulary_validation.intersection(vocabulary))
print("Vocabulary common in Training & Validation Set")
print("Total common words: {}, sample->{}".format(len(CommonWords),CommonWords[0:3]))
# Out:
# ----------------------------------------------------------------------------------------------------
# Total unique vocab
# Training set->12088 Validation set->1820
#
# ----------------------------------------------------------------------------------------------------
# Vocabulary only in Validation Set (not in Training set)
# Total Unknown words: 320, sample->['English-speaking', 'Unless', '8.06']
#
# ----------------------------------------------------------------------------------------------------
# Vocabulary common in Training & Validation Set
# Total common words: 1500, sample->['copies', 'computers', 'plus']

# %% [markdown]
# ### Solve the problem of unknown words

# %%
UnknownWords[0:10]
# Out:
# ['English-speaking',
#  'Unless',
#  '8.06',
#  'tags',
#  "C'mon",
#  '*T*-139',
#  'leaky',
#  'Andersson',
#  'mentioned',
#  'recyclability']

# %%
# This is a rule based tagger that will apply the most common cardinal rule to identify Number and X (unknown) formed due
# to numbers or special characters like $,*.
# Examples: Street-50, **T**, 237, 236,000
def cardinal_X_tagger(word):
    patterns = [
    (r'^[aA-zZ].*[0-9]+','NOUN'),  #Flat/Door Number, Street Number
    (r'^(0|([*|-|$].*))','X'), #Any special form of number like *T* *a-767, 0
    (r'[0-9].?[,\/]?[0-9]*','NUM'),# Any Form of number    
    ]
    regextagger=nltk.RegexpTagger(patterns)
    return regextagger.tag(word)

# %%
# This is a rule based tagger that will apply the most common morpholigical rules of English
# Rule 1: Anything formed with a pattern num-alphabets will be Adjective example 230-seats
# Rule 2: Anything with all capital letters and important Salutations will be treated as Noun ex: Mr. Mrs. Md, CIA
# Rule 3: Anything ending with 'ed' or 'ing' or 'es' will be considered as verb example running, walked
# Rule 4: Anything ending with s or 's will be considered as Noun example 
# Rule 5: Anything with starting letter as capital followed by all small letters will be treated as Noun ex: Testimony, Sir, Mrs
def english_morphological_tagger(word):
    patterns = [
    (r'^([0-9]|[aA-zZ])+\-[aA-zZ]*$','ADJ'), #adjective like 100-megabytes 237-Seats
    (r'^[A-Z]+([a-z]{1,2})?\.?$','NOUN'),# Capitalization rule of English and Salutation
    (r'[aA-zZ]+(\'s|s)$', 'NOUN'),             # possessive nouns & plural nouns
    (r'^[A-Z]{1}[a-z]*$','NOUN'),
    (r'[aA-zZ]+(ed|ing|es)$', 'VERB')
    ]
    regextagger=nltk.RegexpTagger(patterns)
    status=regextagger.tag(word)
    return status

# %%
# cardinal_X_tagger(['0.28'])
# english_morphological_tagger(['Soviet'])
tagged_seq = Viterbi(['Soviet'],backoff=[cardinal_X_tagger,english_morphological_tagger])
tagged_seq
# Out:
# [('Soviet', 'ADJ')]

# %% [markdown]
# #### Evaluating tagging accuracy

# %% [markdown]
# > Vanila Viterbi Algorithm

# %%
# tagging the test sentences
tagged_seq = Viterbi(validation_tagged_words)

# %%
check = [i for i, j in zip(tagged_seq, validation_run_base) if i == j] 
accuracy = len(check)/len(tagged_seq)
print(accuracy)
incorrect_tagged_cases = [j for i, j in enumerate(zip(tagged_seq, validation_run_base)) if j[0]!=j[1]]
# Out:
# 0.9038701622971286

# %%
incorrect_tagged_cases
# Out:
# [(('resumption', 'ADV'), ('resumption', 'NOUN')),
#  (('shuttle', 'ADV'), ('shuttle', 'NOUN')),
#  (('expendable', 'ADV'), ('expendable', 'ADJ')),
#  (('launch-vehicle', 'ADV'), ('launch-vehicle', 'NOUN')),
#  (('engines', 'ADV'), ('engines', 'NOUN')),
#  (('two-letter', 'ADV'), ('two-letter', 'ADJ')),
#  (('consonant', 'ADV'), ('consonant', 'ADJ')),
#  (('sounds', 'VERB'), ('sounds', 'NOUN')),
#  (('sounds', 'VERB'), ('sounds', 'NOUN')),
#  (('to', 'PRT'), ('to', 'ADP')),
#  (('exclusion', 'ADV'), ('exclusion', 'NOUN')),
#  (('sounds', 'VERB'), ('sounds', 'NOUN')),
#  (('Heiwado', 'ADV'), ('Heiwado', 'NOUN')),
#  (('18.3', 'ADV'), ('18.3', 'NUM')),
#  (('Continental', 'ADV'), ('Continental', 'NOUN')),
#  (('Baking', 'ADV'), ('Baking', 'NOUN')),
#  (('bread', 'ADV'), ('bread', 'NOUN')),
#  (('excess', 'ADJ'), ('excess', 'NOUN')),
#  (('percent', 'ADV'), ('percent', 'NOUN')),
#  (('newsstand', 'ADV'), ('newsstand', 'NOUN')),
#  (('freeway', 'ADV'), ('freeway', 'NOUN')),
#  (('inevitable', 'ADV'), ('inevitable', 'ADJ')),
#  (('places', 'NOUN'), ('places', 'VERB')),
#  (('Advice', 'ADV'), ('Advice', 'NOUN')),
#  (('Consent', 'ADV'), ('Consent', 'NOUN')),
#  (('appoint', 'ADV'), ('appoint', 'VERB')),
#  (('ambassadors', 'ADV'), ('ambassadors', 'NOUN')),
#  (('sketching', 'ADV'), ('sketching', 'VERB')),
#  (('passers-by', 'ADV'), ('passers-by', 'NOUN')),
#  (('forecasting', 'ADV'), ('forecasting', 'VERB')),
#  (('down', 'ADV'), ('down', 'ADP')),
#  (('Sumitomo', 'ADV'), ('Sumitomo', 'NOUN')),
#  (('Metal', 'ADV'), ('Metal', 'NOUN')),
#  (('692', 'ADV'), ('692', 'NUM')),
#  (('960', 'ADV'), ('960', 'NUM')),
#  (('including', 'VERB'), ('including', 'ADP')),
#  (('Greece', 'ADV'), ('Greece', 'NOUN')),
#  (('deemed', 'ADV'), ('deemed', 'VERB')),
#  (('less-serious', 'ADV'), ('less-serious', 'ADJ')),
#  (('restricts', 'ADV'), ('restricts', 'VERB')),
#  (('advertising', 'VERB'), ('advertising', 'NOUN')),
#  (('designated', 'ADV'), ('designated', 'VERB')),
#  (('inauspicious', 'ADV'), ('inauspicious', 'ADJ')),
#  (('beginning', 'VERB'), ('beginning', 'NOUN')),
#  (('BRIEFS', 'ADV'), ('BRIEFS', 'NOUN')),
#  (('Everything', 'ADV'), ('Everything', 'NOUN')),
#  (('over', 'ADP'), ('over', 'PRT')),
#  (('Christian', 'ADJ'), ('Christian', 'NOUN')),
#  (('Andersson', 'ADV'), ('Andersson', 'NOUN')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('Handelsbanken', 'ADV'), ('Handelsbanken', 'NOUN')),
#  (('off', 'PRT'), ('off', 'ADP')),
#  (('finance', 'VERB'), ('finance', 'NOUN')),
#  (('modification', 'ADV'), ('modification', 'NOUN')),
#  (('*-130', 'ADV'), ('*-130', 'X')),
#  (('opening', 'NOUN'), ('opening', 'VERB')),
#  (('approached', 'ADV'), ('approached', 'VERB')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('Gringo', 'ADV'), ('Gringo', 'NOUN')),
#  (('confused', 'VERB'), ('confused', 'ADJ')),
#  (('rendering', 'ADV'), ('rendering', 'NOUN')),
#  (('Fuentes', 'ADV'), ('Fuentes', 'NOUN')),
#  (('Mexican', 'ADV'), ('Mexican', 'NOUN')),
#  (('Revolution', 'ADV'), ('Revolution', 'NOUN')),
#  (('try', 'VERB'), ('try', 'NOUN')),
#  (('favor', 'VERB'), ('favor', 'NOUN')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('Funny', 'NOUN'), ('Funny', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('3.55', 'ADV'), ('3.55', 'NUM')),
#  (('1.4', 'ADV'), ('1.4', 'NUM')),
#  (('establish', 'ADV'), ('establish', 'VERB')),
#  (('standing', 'ADJ'), ('standing', 'NOUN')),
#  (('sue', 'ADV'), ('sue', 'VERB')),
#  (('broad-based', 'ADV'), ('broad-based', 'ADJ')),
#  (('very', 'ADV'), ('very', 'ADJ')),
#  (('livelihood', 'ADV'), ('livelihood', 'NOUN')),
#  (('Australian', 'NOUN'), ('Australian', 'ADJ')),
#  (('excise', 'VERB'), ('excise', 'ADJ')),
#  (('before', 'ADP'), ('before', 'ADV')),
#  (('uncanny', 'ADV'), ('uncanny', 'ADJ')),
#  (('public', 'ADJ'), ('public', 'NOUN')),
#  (('responds', 'ADV'), ('responds', 'VERB')),
#  (('Paso', 'ADV'), ('Paso', 'NOUN')),
#  (('boots', 'ADV'), ('boots', 'NOUN')),
#  (('leather', 'ADV'), ('leather', 'NOUN')),
#  (('preferred', 'ADJ'), ('preferred', 'VERB')),
#  (('accrue', 'ADV'), ('accrue', 'VERB')),
#  (('59.6', 'ADV'), ('59.6', 'NUM')),
#  (('contractors', 'ADV'), ('contractors', 'NOUN')),
#  (('unloaded', 'ADV'), ('unloaded', 'ADJ')),
#  (('weight', 'ADV'), ('weight', 'NOUN')),
#  (('round-trip', 'ADV'), ('round-trip', 'ADJ')),
#  (('Trans', 'ADV'), ('Trans', 'NOUN')),
#  (('Riviera', 'ADV'), ('Riviera', 'NOUN')),
#  (('longer', 'ADV'), ('longer', 'ADJ')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('133.7', 'ADV'), ('133.7', 'NUM')),
#  (('94', 'ADV'), ('94', 'NUM')),
#  (('Continuing', 'ADV'), ('Continuing', 'VERB')),
#  (('demand', 'VERB'), ('demand', 'NOUN')),
#  (('realestate', 'ADV'), ('realestate', 'VERB')),
#  (('will', 'VERB'), ('will', 'NOUN')),
#  (('Behind', 'ADV'), ('Behind', 'ADP')),
#  (('hoopla', 'ADV'), ('hoopla', 'NOUN')),
#  (('heavy-duty', 'ADV'), ('heavy-duty', 'ADJ')),
#  (('aspires', 'ADV'), ('aspires', 'VERB')),
#  (('external', 'ADV'), ('external', 'ADJ')),
#  (('Miguel', 'ADV'), ('Miguel', 'NOUN')),
#  (('Alurralde', 'ADV'), ('Alurralde', 'NOUN')),
#  (('U.S.-Japan', 'ADV'), ('U.S.-Japan', 'ADJ')),
#  (('minus', 'CONJ'), ('minus', 'NOUN')),
#  (('timing', 'ADV'), ('timing', 'NOUN')),
#  (('issue', 'VERB'), ('issue', 'NOUN')),
#  (('rectified', 'ADV'), ('rectified', 'VERB')),
#  (('down', 'ADV'), ('down', 'PRT')),
#  (('inquiring', 'ADV'), ('inquiring', 'VERB')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('market-oriented', 'ADV'), ('market-oriented', 'ADJ')),
#  (('regulations', 'ADV'), ('regulations', 'NOUN')),
#  (('6.03', 'ADV'), ('6.03', 'NUM')),
#  (('attributes', 'ADV'), ('attributes', 'VERB')),
#  (('philosophy', 'ADV'), ('philosophy', 'NOUN')),
#  (('concentrating', 'ADV'), ('concentrating', 'VERB')),
#  (('twisting', 'ADV'), ('twisting', 'VERB')),
#  (('doctrine', 'ADV'), ('doctrine', 'NOUN')),
#  (('Lead', 'ADV'), ('Lead', 'ADJ')),
#  (('Scotia', 'ADV'), ('Scotia', 'NOUN')),
#  (('McLeod', 'ADV'), ('McLeod', 'NOUN')),
#  (('RBC', 'ADV'), ('RBC', 'NOUN')),
#  (('Dominion', 'ADV'), ('Dominion', 'NOUN')),
#  (('Public', 'NOUN'), ('Public', 'ADJ')),
#  (('favors', 'ADV'), ('favors', 'VERB')),
#  (('accompany', 'ADV'), ('accompany', 'VERB')),
#  (('lives', 'VERB'), ('lives', 'NOUN')),
#  (('pain', 'ADV'), ('pain', 'NOUN')),
#  (('unanimous', 'ADV'), ('unanimous', 'ADJ')),
#  (('Commodities', 'ADV'), ('Commodities', 'NOUN')),
#  (('129.91', 'ADV'), ('129.91', 'NUM')),
#  (('0.28', 'ADV'), ('0.28', 'NUM')),
#  (('131.01', 'ADV'), ('131.01', 'NUM')),
#  (('1.17', 'ADV'), ('1.17', 'NUM')),
#  (('Unless', 'ADV'), ('Unless', 'ADP')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-176', 'ADV'), ('*T*-176', 'X')),
#  (('Explorer', 'ADV'), ('Explorer', 'NOUN')),
#  (('sport-utility', 'ADV'), ('sport-utility', 'ADJ')),
#  (('reflection', 'ADV'), ('reflection', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('that', 'ADP'), ('that', 'ADV')),
#  (('comprehensive', 'ADV'), ('comprehensive', 'ADJ')),
#  (('dismayed', 'ADV'), ('dismayed', 'ADJ')),
#  (('stacking', 'ADV'), ('stacking', 'VERB')),
#  (('deck', 'ADV'), ('deck', 'NOUN')),
#  (('scaring', 'ADV'), ('scaring', 'VERB')),
#  (('Raymond', 'ADV'), ('Raymond', 'NOUN')),
#  (('early', 'ADJ'), ('early', 'ADV')),
#  (('injecting', 'ADV'), ('injecting', 'VERB')),
#  (('muzzling', 'ADV'), ('muzzling', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('recommendation', 'ADV'), ('recommendation', 'NOUN')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('pains', 'ADV'), ('pains', 'NOUN')),
#  (('bid', 'NOUN'), ('bid', 'VERB')),
#  (('equivalent', 'ADJ'), ('equivalent', 'NOUN')),
#  (('penny', 'ADV'), ('penny', 'NOUN')),
#  (('spurns', 'ADV'), ('spurns', 'VERB')),
#  (('leading', 'VERB'), ('leading', 'ADJ')),
#  (('no', 'DET'), ('no', 'ADV')),
#  (('subject', 'NOUN'), ('subject', 'ADJ')),
#  (('vicissitudes', 'ADV'), ('vicissitudes', 'NOUN')),
#  (('plus', 'CONJ'), ('plus', 'NOUN')),
#  (('Riviera', 'ADV'), ('Riviera', 'NOUN')),
#  (('forecast', 'VERB'), ('forecast', 'NOUN')),
#  (('plaintive', 'ADV'), ('plaintive', 'ADJ')),
#  (('high-minded', 'ADV'), ('high-minded', 'ADJ')),
#  (('note', 'VERB'), ('note', 'NOUN')),
#  (('assurance', 'ADV'), ('assurance', 'NOUN')),
#  (('reading', 'NOUN'), ('reading', 'VERB')),
#  (('sticky', 'ADV'), ('sticky', 'ADJ')),
#  (('fingers', 'ADV'), ('fingers', 'NOUN')),
#  (('sweaty', 'ADV'), ('sweaty', 'ADJ')),
#  (('riding', 'ADV'), ('riding', 'VERB')),
#  (('industrywide', 'ADV'), ('industrywide', 'ADJ')),
#  (('operating', 'NOUN'), ('operating', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('unlikely', 'ADV'), ('unlikely', 'ADJ')),
#  (('quote', 'ADV'), ('quote', 'VERB')),
#  (('drop-in', 'ADV'), ('drop-in', 'ADJ')),
#  (('homeless', 'ADJ'), ('homeless', 'NOUN')),
#  (('robbed', 'ADV'), ('robbed', 'VERB')),
#  (('Kathryn', 'ADV'), ('Kathryn', 'NOUN')),
#  (('McAuley', 'ADV'), ('McAuley', 'NOUN')),
#  (('double-A', 'ADV'), ('double-A', 'ADJ')),
#  (('rating', 'VERB'), ('rating', 'NOUN')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('plugged', 'ADV'), ('plugged', 'VERB')),
#  (('right', 'NOUN'), ('right', 'ADV')),
#  (('rebuilding', 'ADV'), ('rebuilding', 'VERB')),
#  (('angle', 'ADV'), ('angle', 'NOUN')),
#  (("'80s", 'ADV'), ("'80s", 'NUM')),
#  (('citizen-sparked', 'ADV'), ('citizen-sparked', 'ADJ')),
#  (('ballots', 'ADV'), ('ballots', 'NOUN')),
#  (('odd-year', 'ADV'), ('odd-year', 'ADJ')),
#  (('858,000', 'ADV'), ('858,000', 'NUM')),
#  (('injuring', 'ADV'), ('injuring', 'VERB')),
#  (('Average', 'NOUN'), ('Average', 'ADJ')),
#  (('negotiable', 'ADV'), ('negotiable', 'ADJ')),
#  (('C.D.s', 'ADV'), ('C.D.s', 'NOUN')),
#  (('crunch', 'ADV'), ('crunch', 'NOUN')),
#  (('crunch', 'ADV'), ('crunch', 'NOUN')),
#  (('crunch', 'ADV'), ('crunch', 'NOUN')),
#  (('bang', 'ADV'), ('bang', 'NOUN')),
#  (('bang', 'ADV'), ('bang', 'NOUN')),
#  (('bang', 'ADV'), ('bang', 'NOUN')),
#  (('above', 'ADP'), ('above', 'ADV')),
#  (('obvious', 'ADV'), ('obvious', 'ADJ')),
#  (('exit', 'ADV'), ('exit', 'NOUN')),
#  (('prayer', 'ADV'), ('prayer', 'NOUN')),
#  (('Except', 'ADV'), ('Except', 'ADP')),
#  (('counts', 'VERB'), ('counts', 'NOUN')),
#  (('charging', 'ADV'), ('charging', 'VERB')),
#  (('early', 'ADJ'), ('early', 'ADV')),
#  (('Calif.-based', 'ADV'), ('Calif.-based', 'ADJ')),
#  (('circuit-board', 'ADV'), ('circuit-board', 'NOUN')),
#  (('disposed', 'ADV'), ('disposed', 'VERB')),
#  (('acid', 'ADJ'), ('acid', 'NOUN')),
#  (('caustic', 'ADV'), ('caustic', 'ADJ')),
#  (('sewer', 'ADV'), ('sewer', 'NOUN')),
#  (('leaky', 'ADV'), ('leaky', 'ADJ')),
#  (('unlabeled', 'ADV'), ('unlabeled', 'ADJ')),
#  (('open-top', 'ADV'), ('open-top', 'ADJ')),
#  (('containers', 'ADV'), ('containers', 'NOUN')),
#  (('quitting', 'ADV'), ('quitting', 'VERB')),
#  (('lasted', 'ADV'), ('lasted', 'VERB')),
#  (('tired', 'ADV'), ('tired', 'ADJ')),
#  (('stigma', 'ADV'), ('stigma', 'NOUN')),
#  (('campaigner', 'ADV'), ('campaigner', 'NOUN')),
#  (('Rozell', 'ADV'), ('Rozell', 'NOUN')),
#  (('equal-opportunity', 'ADV'), ('equal-opportunity', 'NOUN')),
#  (('suit', 'VERB'), ('suit', 'NOUN')),
#  (('skirmishes', 'ADV'), ('skirmishes', 'NOUN')),
#  (('carefree', 'ADV'), ('carefree', 'ADJ')),
#  (('marrow', 'ADV'), ('marrow', 'NOUN')),
#  (('blood-cell', 'ADV'), ('blood-cell', 'NOUN')),
#  (('proscribes', 'ADV'), ('proscribes', 'VERB')),
#  (('abridging', 'ADV'), ('abridging', 'VERB')),
#  (('So', 'ADV'), ('So', 'ADP')),
#  (('deemed', 'ADV'), ('deemed', 'VERB')),
#  (('enough', 'ADJ'), ('enough', 'ADV')),
#  (('merit', 'NOUN'), ('merit', 'VERB')),
#  (('accelerated', 'ADJ'), ('accelerated', 'VERB')),
#  (('301', 'ADV'), ('301', 'NUM')),
#  (('Individual', 'ADV'), ('Individual', 'ADJ')),
#  (('2.95', 'ADV'), ('2.95', 'NUM')),
#  (('yearly', 'ADV'), ('yearly', 'ADJ')),
#  (('clear', 'ADJ'), ('clear', 'VERB')),
#  (('blames', 'ADV'), ('blames', 'VERB')),
#  (('around', 'ADP'), ('around', 'PRT')),
#  (('accountants', 'ADV'), ('accountants', 'NOUN')),
#  (('blinks', 'ADV'), ('blinks', 'VERB')),
#  (('disaster-assistance', 'ADV'), ('disaster-assistance', 'ADJ')),
#  (('50-state', 'ADV'), ('50-state', 'ADJ')),
#  (('study', 'VERB'), ('study', 'NOUN')),
#  (('school-research', 'ADV'), ('school-research', 'ADJ')),
#  (('if', 'ADP'), ('if', 'ADJ')),
#  (('pride', 'ADV'), ('pride', 'NOUN')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('Norwegian', 'ADV'), ('Norwegian', 'NOUN')),
#  (('Japanese', 'ADJ'), ('Japanese', 'NOUN')),
#  (('fluent', 'ADV'), ('fluent', 'ADJ')),
#  (('lyrics', 'ADV'), ('lyrics', 'NOUN')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('published', 'ADV'), ('published', 'VERB')),
#  (('brief', 'ADJ'), ('brief', 'VERB')),
#  (('Medical', 'NOUN'), ('Medical', 'ADJ')),
#  (('transplantation', 'ADV'), ('transplantation', 'NOUN')),
#  (('humans', 'ADV'), ('humans', 'NOUN')),
#  (('juvenile', 'ADV'), ('juvenile', 'ADJ')),
#  (('diabetes', 'ADV'), ('diabetes', 'NOUN')),
#  (('degenerative', 'ADV'), ('degenerative', 'ADJ')),
#  (('Huntington', 'ADV'), ('Huntington', 'NOUN')),
#  (('*T*-139', 'ADV'), ('*T*-139', 'X')),
#  (('tie-breaking', 'ADV'), ('tie-breaking', 'ADJ')),
#  (('insider', 'ADV'), ('insider', 'NOUN')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('Value', 'ADV'), ('Value', 'NOUN')),
#  (('1.56', 'ADV'), ('1.56', 'NUM')),
#  (('372.14', 'ADV'), ('372.14', 'NUM')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('walking', 'ADV'), ('walking', 'VERB')),
#  (('shift', 'ADV'), ('shift', 'NOUN')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('drastic', 'ADV'), ('drastic', 'ADJ')),
#  (('shift', 'ADV'), ('shift', 'NOUN')),
#  (('sacrificing', 'ADV'), ('sacrificing', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-140', 'ADV'), ('*T*-140', 'X')),
#  (('Henderson', 'ADV'), ('Henderson', 'NOUN')),
#  (('51-year-old', 'ADV'), ('51-year-old', 'ADJ')),
#  (('Ian', 'ADV'), ('Ian', 'NOUN')),
#  (('*T*-161', 'ADV'), ('*T*-161', 'X')),
#  (('retiring', 'ADV'), ('retiring', 'VERB')),
#  (('Short', 'ADV'), ('Short', 'ADJ')),
#  (('total', 'ADJ'), ('total', 'NOUN')),
#  (('middle-ground', 'ADV'), ('middle-ground', 'ADJ')),
#  (('away', 'ADV'), ('away', 'PRT')),
#  (('enjoy', 'ADV'), ('enjoy', 'VERB')),
#  (('trade', 'VERB'), ('trade', 'NOUN')),
#  (('Overseas', 'ADV'), ('Overseas', 'NOUN')),
#  (('Private', 'ADJ'), ('Private', 'NOUN')),
#  (('bell-ringing', 'ADV'), ('bell-ringing', 'ADJ')),
#  (('Ancient', 'ADV'), ('Ancient', 'NOUN')),
#  (('Youths', 'ADV'), ('Youths', 'NOUN')),
#  (('1637', 'ADV'), ('1637', 'NUM')),
#  (('male-only', 'ADV'), ('male-only', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-230', 'ADV'), ('*T*-230', 'X')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('galling', 'ADV'), ('galling', 'ADJ')),
#  (('sole', 'ADV'), ('sole', 'ADJ')),
#  (('Cathedral', 'ADV'), ('Cathedral', 'NOUN')),
#  (('Westminster', 'ADV'), ('Westminster', 'NOUN')),
#  (('Abbey', 'ADV'), ('Abbey', 'NOUN')),
#  (('FOREIGN', 'ADV'), ('FOREIGN', 'NOUN')),
#  (('13.50', 'ADV'), ('13.50', 'NUM')),
#  (('4.875', 'ADV'), ('4.875', 'NUM')),
#  (('70.2', 'ADV'), ('70.2', 'NUM')),
#  (('seafood', 'ADV'), ('seafood', 'NOUN')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('finance', 'VERB'), ('finance', 'NOUN')),
#  (('better', 'ADJ'), ('better', 'ADV')),
#  (('illustrates', 'ADV'), ('illustrates', 'VERB')),
#  (('usurp', 'ADV'), ('usurp', 'VERB')),
#  (('609', 'ADV'), ('609', 'NUM')),
#  (('executive-office', 'ADV'), ('executive-office', 'NOUN')),
#  (('administer', 'ADV'), ('administer', 'VERB')),
#  (('disapproved', 'ADV'), ('disapproved', 'VERB')),
#  (('*-58', 'ADV'), ('*-58', 'X')),
#  (('disapproval', 'ADV'), ('disapproval', 'NOUN')),
#  (('accordance', 'ADV'), ('accordance', 'NOUN')),
#  (('applicable', 'ADV'), ('applicable', 'ADJ')),
#  (('upper', 'ADV'), ('upper', 'ADJ')),
#  (('trimming', 'ADV'), ('trimming', 'VERB')),
#  (('tows', 'ADV'), ('tows', 'NOUN')),
#  (("C'mon", 'ADV'), ("C'mon", 'VERB')),
#  (('boyfriends', 'ADV'), ('boyfriends', 'NOUN')),
#  (('Four', 'ADV'), ('Four', 'NUM')),
#  (('diagnosed', 'ADV'), ('diagnosed', 'VERB')),
#  (('Areas', 'ADV'), ('Areas', 'NOUN')),
#  (('dusty', 'ADV'), ('dusty', 'ADJ')),
#  (('F.H.', 'ADV'), ('F.H.', 'NOUN')),
#  (('Australian', 'NOUN'), ('Australian', 'ADJ')),
#  (('reflection', 'ADV'), ('reflection', 'NOUN')),
#  (('view', 'NOUN'), ('view', 'VERB')),
#  (('mentioned', 'ADV'), ('mentioned', 'VERB')),
#  (('ECONOMIC', 'ADV'), ('ECONOMIC', 'ADJ')),
#  (('GROWTH', 'ADV'), ('GROWTH', 'NOUN')),
#  (('APPEARS', 'ADV'), ('APPEARS', 'VERB')),
#  (('leveling', 'ADV'), ('leveling', 'VERB')),
#  (('TIRED', 'ADV'), ('TIRED', 'ADJ')),
#  (('OF', 'ADV'), ('OF', 'ADP')),
#  (('TRIMMING', 'ADV'), ('TRIMMING', 'VERB')),
#  (('Domaine', 'ADV'), ('Domaine', 'NOUN')),
#  (('la', 'ADV'), ('la', 'DET')),
#  (('most', 'ADJ'), ('most', 'ADV')),
#  (('vineyard', 'ADV'), ('vineyard', 'NOUN')),
#  (('commanded', 'ADV'), ('commanded', 'VERB')),
#  (('three-digit', 'ADV'), ('three-digit', 'ADJ')),
#  (('tags', 'ADV'), ('tags', 'NOUN')),
#  (('queuing', 'ADV'), ('queuing', 'VERB')),
#  (('working', 'NOUN'), ('working', 'VERB')),
#  (('unsympathetic', 'ADV'), ('unsympathetic', 'ADJ')),
#  (('oblivion', 'ADV'), ('oblivion', 'NOUN')),
#  (('start-up', 'NOUN'), ('start-up', 'ADJ')),
#  (('softer', 'ADV'), ('softer', 'ADJ')),
#  (('motor-home', 'ADV'), ('motor-home', 'NOUN')),
#  (('regulations', 'ADV'), ('regulations', 'NOUN')),
#  (('imply', 'ADV'), ('imply', 'VERB')),
#  (('three-quarters', 'ADV'), ('three-quarters', 'NOUN')),
#  (('following', 'VERB'), ('following', 'NOUN')),
#  (('9.3', 'ADV'), ('9.3', 'NUM')),
#  (('Majority', 'ADV'), ('Majority', 'NOUN')),
#  (('Whip', 'ADV'), ('Whip', 'NOUN')),
#  (('Pa', 'ADV'), ('Pa', 'NOUN')),
#  (('English-speaking', 'ADV'), ('English-speaking', 'ADJ')),
#  (('Barbados', 'ADV'), ('Barbados', 'NOUN')),
#  (('Signs', 'ADV'), ('Signs', 'NOUN')),
#  (('slowing', 'NOUN'), ('slowing', 'VERB')),
#  (('Hayes', 'ADV'), ('Hayes', 'NOUN')),
#  (('Dale', 'ADV'), ('Dale', 'NOUN')),
#  (('Heatherington', 'ADV'), ('Heatherington', 'NOUN')),
#  (('co-developers', 'ADV'), ('co-developers', 'NOUN')),
#  (('modems', 'ADV'), ('modems', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('share', 'NOUN'), ('share', 'VERB')),
#  (('Left', 'ADV'), ('Left', 'VERB')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('though', 'ADP'), ('though', 'ADV')),
#  (('recyclability', 'ADV'), ('recyclability', 'NOUN')),
#  (('arbitrager', 'ADV'), ('arbitrager', 'NOUN')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('warranties', 'ADV'), ('warranties', 'NOUN')),
#  (('estimates', 'NOUN'), ('estimates', 'VERB')),
#  (('total', 'VERB'), ('total', 'NOUN')),
#  (('vs.', 'CONJ'), ('vs.', 'ADP')),
#  (('%', 'NOUN'), ('%', 'ADJ')),
#  (('corn-buying', 'ADV'), ('corn-buying', 'ADJ')),
#  (('binge', 'ADV'), ('binge', 'NOUN')),
#  (('Soviet', 'ADJ'), ('Soviet', 'NOUN')),
#  (('bottlenecks', 'ADV'), ('bottlenecks', 'NOUN')),
#  (('pipeline', 'ADV'), ('pipeline', 'NOUN')),
#  (('Encouraged', 'ADV'), ('Encouraged', 'ADJ')),
#  (('honor', 'VERB'), ('honor', 'NOUN')),
#  (('vague', 'ADV'), ('vague', 'ADJ')),
#  (('mushy', 'ADV'), ('mushy', 'ADJ')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('viewpoints', 'ADV'), ('viewpoints', 'NOUN')),
#  (('out', 'PRT'), ('out', 'ADV')),
#  (('deliberating', 'ADV'), ('deliberating', 'VERB')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('breathtaking', 'ADV'), ('breathtaking', 'ADJ')),
#  (('attempts', 'VERB'), ('attempts', 'NOUN')),
#  (('public', 'ADJ'), ('public', 'NOUN')),
#  (('elaborate', 'VERB'), ('elaborate', 'ADJ')),
#  (('piracy', 'ADV'), ('piracy', 'NOUN')),
#  (('disregard', 'ADV'), ('disregard', 'NOUN')),
#  (('soldiers', 'ADV'), ('soldiers', 'NOUN')),
#  (('*T*-246', 'ADV'), ('*T*-246', 'X')),
#  (('past', 'ADJ'), ('past', 'NOUN')),
#  (('CERTIFICATES', 'ADV'), ('CERTIFICATES', 'NOUN')),
#  (('OF', 'ADV'), ('OF', 'ADP')),
#  (('DEPOSIT', 'ADV'), ('DEPOSIT', 'NOUN')),
#  (('8.06', 'ADV'), ('8.06', 'NUM')),
#  (('parts-engineering', 'ADV'), ('parts-engineering', 'ADJ')),
#  (('charge', 'VERB'), ('charge', 'NOUN')),
#  (('12.09', 'ADV'), ('12.09', 'NUM')),
#  (('little', 'ADV'), ('little', 'ADJ')),
#  (('establish', 'ADV'), ('establish', 'VERB')),
#  (('trafficking', 'ADV'), ('trafficking', 'NOUN')),
#  (('Andean', 'ADV'), ('Andean', 'ADJ')),
#  (('worth', 'ADJ'), ('worth', 'ADP')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('Nine', 'ADV'), ('Nine', 'NUM')),
#  (('Tailors', 'ADV'), ('Tailors', 'NOUN')),
#  (('7.8', 'ADV'), ('7.8', 'NUM')),
#  (('reflection', 'ADV'), ('reflection', 'NOUN')),
#  (('leveling', 'ADV'), ('leveling', 'VERB')),
#  (('off', 'ADP'), ('off', 'PRT')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('British', 'ADJ'), ('British', 'NOUN')),
#  (('payable', 'ADV'), ('payable', 'ADJ')),
#  (('Jan.', 'ADV'), ('Jan.', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('captivating', 'ADV'), ('captivating', 'ADJ')),
#  (('most', 'ADJ'), ('most', 'ADV')),
#  (('angle', 'ADV'), ('angle', 'NOUN')),
#  (('disagreeable', 'ADV'), ('disagreeable', 'ADJ'))]

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %% [markdown]
# > Modified Vanila Viterbi Algorithm
# > > The two modification taggers cardinal_X_tagger,english_morphological_tagger passed and applied in chaining
#
#   - Note: A modification in Verbitri algorithm, if Emission probability of all Tags is 0 than we will consider only Transition probability

# %%
tagged_seq = Viterbi(validation_tagged_words,backoff=[cardinal_X_tagger,english_morphological_tagger])

# %%
check = [i for i, j in zip(tagged_seq, validation_run_base) if i == j] 
accuracy = len(check)/len(tagged_seq)
print(accuracy)
incorrect_tagged_cases = [j for i, j in enumerate(zip(tagged_seq, validation_run_base)) if j[0]!=j[1]]
# Out:
# 0.9506866416978776

# %%
incorrect_tagged_cases
# Out:
# [(('expendable', 'DET'), ('expendable', 'ADJ')),
#  (('launch-vehicle', 'ADJ'), ('launch-vehicle', 'NOUN')),
#  (('consonant', 'NOUN'), ('consonant', 'ADJ')),
#  (('sounds', 'VERB'), ('sounds', 'NOUN')),
#  (('sounds', 'VERB'), ('sounds', 'NOUN')),
#  (('to', 'PRT'), ('to', 'ADP')),
#  (('sounds', 'VERB'), ('sounds', 'NOUN')),
#  (('bread', 'DET'), ('bread', 'NOUN')),
#  (('excess', 'ADJ'), ('excess', 'NOUN')),
#  (('inevitable', 'VERB'), ('inevitable', 'ADJ')),
#  (('places', 'NOUN'), ('places', 'VERB')),
#  (('appoint', 'NOUN'), ('appoint', 'VERB')),
#  (('passers-by', 'ADJ'), ('passers-by', 'NOUN')),
#  (('down', 'ADV'), ('down', 'ADP')),
#  (('including', 'VERB'), ('including', 'ADP')),
#  (('restricts', 'NOUN'), ('restricts', 'VERB')),
#  (('inauspicious', 'NOUN'), ('inauspicious', 'ADJ')),
#  (('beginning', 'VERB'), ('beginning', 'NOUN')),
#  (('over', 'ADP'), ('over', 'PRT')),
#  (('Christian', 'ADJ'), ('Christian', 'NOUN')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('off', 'PRT'), ('off', 'ADP')),
#  (('finance', 'VERB'), ('finance', 'NOUN')),
#  (('opening', 'NOUN'), ('opening', 'VERB')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('confused', 'VERB'), ('confused', 'ADJ')),
#  (('rendering', 'VERB'), ('rendering', 'NOUN')),
#  (('try', 'VERB'), ('try', 'NOUN')),
#  (('favor', 'VERB'), ('favor', 'NOUN')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('Funny', 'NOUN'), ('Funny', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('establish', 'X'), ('establish', 'VERB')),
#  (('very', 'ADV'), ('very', 'ADJ')),
#  (('livelihood', 'VERB'), ('livelihood', 'NOUN')),
#  (('Australian', 'NOUN'), ('Australian', 'ADJ')),
#  (('excise', 'VERB'), ('excise', 'ADJ')),
#  (('before', 'ADP'), ('before', 'ADV')),
#  (('uncanny', 'X'), ('uncanny', 'ADJ')),
#  (('public', 'ADJ'), ('public', 'NOUN')),
#  (('responds', 'NOUN'), ('responds', 'VERB')),
#  (('preferred', 'ADJ'), ('preferred', 'VERB')),
#  (('accrue', 'X'), ('accrue', 'VERB')),
#  (('unloaded', 'VERB'), ('unloaded', 'ADJ')),
#  (('weight', 'X'), ('weight', 'NOUN')),
#  (('longer', 'ADV'), ('longer', 'ADJ')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('Continuing', 'NOUN'), ('Continuing', 'VERB')),
#  (('will', 'VERB'), ('will', 'NOUN')),
#  (('Behind', 'NOUN'), ('Behind', 'ADP')),
#  (('aspires', 'NOUN'), ('aspires', 'VERB')),
#  (('external', 'VERB'), ('external', 'ADJ')),
#  (('U.S.-Japan', 'X'), ('U.S.-Japan', 'ADJ')),
#  (('minus', 'CONJ'), ('minus', 'NOUN')),
#  (('timing', 'VERB'), ('timing', 'NOUN')),
#  (('down', 'ADV'), ('down', 'PRT')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('attributes', 'NOUN'), ('attributes', 'VERB')),
#  (('Lead', 'NOUN'), ('Lead', 'ADJ')),
#  (('Public', 'NOUN'), ('Public', 'ADJ')),
#  (('favors', 'NOUN'), ('favors', 'VERB')),
#  (('accompany', 'X'), ('accompany', 'VERB')),
#  (('lives', 'VERB'), ('lives', 'NOUN')),
#  (('pain', 'X'), ('pain', 'NOUN')),
#  (('unanimous', 'NOUN'), ('unanimous', 'ADJ')),
#  (('0.28', 'X'), ('0.28', 'NUM')),
#  (('Unless', 'NOUN'), ('Unless', 'ADP')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('reflection', 'DET'), ('reflection', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('that', 'ADP'), ('that', 'ADV')),
#  (('comprehensive', 'DET'), ('comprehensive', 'ADJ')),
#  (('dismayed', 'VERB'), ('dismayed', 'ADJ')),
#  (('early', 'ADJ'), ('early', 'ADV')),
#  (('muzzling', 'VERB'), ('muzzling', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('bid', 'NOUN'), ('bid', 'VERB')),
#  (('equivalent', 'ADJ'), ('equivalent', 'NOUN')),
#  (('spurns', 'NOUN'), ('spurns', 'VERB')),
#  (('leading', 'VERB'), ('leading', 'ADJ')),
#  (('no', 'DET'), ('no', 'ADV')),
#  (('subject', 'NOUN'), ('subject', 'ADJ')),
#  (('plus', 'CONJ'), ('plus', 'NOUN')),
#  (('forecast', 'VERB'), ('forecast', 'NOUN')),
#  (('plaintive', 'NOUN'), ('plaintive', 'ADJ')),
#  (('assurance', 'DET'), ('assurance', 'NOUN')),
#  (('reading', 'NOUN'), ('reading', 'VERB')),
#  (('sticky', 'DET'), ('sticky', 'ADJ')),
#  (('sweaty', 'NOUN'), ('sweaty', 'ADJ')),
#  (('industrywide', 'NOUN'), ('industrywide', 'ADJ')),
#  (('operating', 'NOUN'), ('operating', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('unlikely', 'X'), ('unlikely', 'ADJ')),
#  (('homeless', 'ADJ'), ('homeless', 'NOUN')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('right', 'NOUN'), ('right', 'ADV')),
#  (("'80s", 'NOUN'), ("'80s", 'NUM')),
#  (('Average', 'NOUN'), ('Average', 'ADJ')),
#  (('negotiable', 'DET'), ('negotiable', 'ADJ')),
#  (('crunch', 'VERB'), ('crunch', 'NOUN')),
#  (('above', 'ADP'), ('above', 'ADV')),
#  (('obvious', 'NOUN'), ('obvious', 'ADJ')),
#  (('prayer', 'DET'), ('prayer', 'NOUN')),
#  (('Except', 'NOUN'), ('Except', 'ADP')),
#  (('counts', 'VERB'), ('counts', 'NOUN')),
#  (('early', 'ADJ'), ('early', 'ADV')),
#  (('Calif.-based', 'NOUN'), ('Calif.-based', 'ADJ')),
#  (('circuit-board', 'ADJ'), ('circuit-board', 'NOUN')),
#  (('acid', 'ADJ'), ('acid', 'NOUN')),
#  (('caustic', 'NOUN'), ('caustic', 'ADJ')),
#  (('leaky', 'DET'), ('leaky', 'ADJ')),
#  (('unlabeled', 'VERB'), ('unlabeled', 'ADJ')),
#  (('tired', 'VERB'), ('tired', 'ADJ')),
#  (('equal-opportunity', 'ADJ'), ('equal-opportunity', 'NOUN')),
#  (('carefree', 'X'), ('carefree', 'ADJ')),
#  (('blood-cell', 'ADJ'), ('blood-cell', 'NOUN')),
#  (('proscribes', 'NOUN'), ('proscribes', 'VERB')),
#  (('So', 'ADV'), ('So', 'ADP')),
#  (('enough', 'ADJ'), ('enough', 'ADV')),
#  (('merit', 'NOUN'), ('merit', 'VERB')),
#  (('accelerated', 'ADJ'), ('accelerated', 'VERB')),
#  (('Individual', 'NOUN'), ('Individual', 'ADJ')),
#  (('yearly', 'NOUN'), ('yearly', 'ADJ')),
#  (('clear', 'ADJ'), ('clear', 'VERB')),
#  (('blames', 'NOUN'), ('blames', 'VERB')),
#  (('around', 'ADP'), ('around', 'PRT')),
#  (('blinks', 'NOUN'), ('blinks', 'VERB')),
#  (('if', 'ADP'), ('if', 'ADJ')),
#  (('pride', 'DET'), ('pride', 'NOUN')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('Japanese', 'ADJ'), ('Japanese', 'NOUN')),
#  (('fluent', 'X'), ('fluent', 'ADJ')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('brief', 'ADJ'), ('brief', 'VERB')),
#  (('Medical', 'NOUN'), ('Medical', 'ADJ')),
#  (('juvenile', 'X'), ('juvenile', 'ADJ')),
#  (('degenerative', 'NOUN'), ('degenerative', 'ADJ')),
#  (('commercial', 'NOUN'), ('commercial', 'ADJ')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('out', 'PRT'), ('out', 'ADP')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('drastic', 'NOUN'), ('drastic', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('51-year-old', 'NUM'), ('51-year-old', 'ADJ')),
#  (('Short', 'NOUN'), ('Short', 'ADJ')),
#  (('total', 'ADJ'), ('total', 'NOUN')),
#  (('away', 'ADV'), ('away', 'PRT')),
#  (('trade', 'VERB'), ('trade', 'NOUN')),
#  (('Private', 'ADJ'), ('Private', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('galling', 'VERB'), ('galling', 'ADJ')),
#  (('sole', 'NOUN'), ('sole', 'ADJ')),
#  (('seafood', 'DET'), ('seafood', 'NOUN')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('finance', 'VERB'), ('finance', 'NOUN')),
#  (('better', 'ADJ'), ('better', 'ADV')),
#  (('illustrates', 'NOUN'), ('illustrates', 'VERB')),
#  (('executive-office', 'ADJ'), ('executive-office', 'NOUN')),
#  (('administer', 'NOUN'), ('administer', 'VERB')),
#  (('disapproval', 'DET'), ('disapproval', 'NOUN')),
#  (('accordance', 'DET'), ('accordance', 'NOUN')),
#  (('applicable', 'NOUN'), ('applicable', 'ADJ')),
#  (('upper', 'NOUN'), ('upper', 'ADJ')),
#  (("C'mon", 'NOUN'), ("C'mon", 'VERB')),
#  (('Four', 'NOUN'), ('Four', 'NUM')),
#  (('dusty', 'VERB'), ('dusty', 'ADJ')),
#  (('Australian', 'NOUN'), ('Australian', 'ADJ')),
#  (('reflection', 'DET'), ('reflection', 'NOUN')),
#  (('view', 'NOUN'), ('view', 'VERB')),
#  (('ECONOMIC', 'NOUN'), ('ECONOMIC', 'ADJ')),
#  (('APPEARS', 'NOUN'), ('APPEARS', 'VERB')),
#  (('off', 'PRT'), ('off', 'ADP')),
#  (('TIRED', 'NOUN'), ('TIRED', 'ADJ')),
#  (('OF', 'NOUN'), ('OF', 'ADP')),
#  (('TRIMMING', 'NOUN'), ('TRIMMING', 'VERB')),
#  (('most', 'ADJ'), ('most', 'ADV')),
#  (('vineyard', 'DET'), ('vineyard', 'NOUN')),
#  (('anywhere', 'NOUN'), ('anywhere', 'ADV')),
#  (('working', 'NOUN'), ('working', 'VERB')),
#  (('unsympathetic', 'VERB'), ('unsympathetic', 'ADJ')),
#  (('oblivion', 'DET'), ('oblivion', 'NOUN')),
#  (('start-up', 'NOUN'), ('start-up', 'ADJ')),
#  (('softer', 'NOUN'), ('softer', 'ADJ')),
#  (('motor-home', 'ADJ'), ('motor-home', 'NOUN')),
#  (('imply', 'NOUN'), ('imply', 'VERB')),
#  (('three-quarters', 'ADJ'), ('three-quarters', 'NOUN')),
#  (('following', 'VERB'), ('following', 'NOUN')),
#  (('slowing', 'NOUN'), ('slowing', 'VERB')),
#  (('co-developers', 'ADJ'), ('co-developers', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('share', 'NOUN'), ('share', 'VERB')),
#  (('Left', 'NOUN'), ('Left', 'VERB')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('though', 'ADP'), ('though', 'ADV')),
#  (('recyclability', 'DET'), ('recyclability', 'NOUN')),
#  (('alike', 'VERB'), ('alike', 'ADV')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('differently', 'NOUN'), ('differently', 'ADV')),
#  (('estimates', 'NOUN'), ('estimates', 'VERB')),
#  (('total', 'VERB'), ('total', 'NOUN')),
#  (('vs.', 'CONJ'), ('vs.', 'ADP')),
#  (('%', 'NOUN'), ('%', 'ADJ')),
#  (('Soviet', 'ADJ'), ('Soviet', 'NOUN')),
#  (('Encouraged', 'NOUN'), ('Encouraged', 'ADJ')),
#  (('honor', 'VERB'), ('honor', 'NOUN')),
#  (('vague', 'NOUN'), ('vague', 'ADJ')),
#  (('mushy', 'NOUN'), ('mushy', 'ADJ')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('out', 'PRT'), ('out', 'ADV')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('breathtaking', 'VERB'), ('breathtaking', 'ADJ')),
#  (('attempts', 'VERB'), ('attempts', 'NOUN')),
#  (('public', 'ADJ'), ('public', 'NOUN')),
#  (('elaborate', 'VERB'), ('elaborate', 'ADJ')),
#  (('past', 'ADJ'), ('past', 'NOUN')),
#  (('OF', 'NOUN'), ('OF', 'ADP')),
#  (('charge', 'VERB'), ('charge', 'NOUN')),
#  (('little', 'ADV'), ('little', 'ADJ')),
#  (('trafficking', 'VERB'), ('trafficking', 'NOUN')),
#  (('Andean', 'NOUN'), ('Andean', 'ADJ')),
#  (('worth', 'ADJ'), ('worth', 'ADP')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('Nine', 'NOUN'), ('Nine', 'NUM')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('British', 'ADJ'), ('British', 'NOUN')),
#  (('payable', 'X'), ('payable', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('captivating', 'VERB'), ('captivating', 'ADJ')),
#  (('most', 'ADJ'), ('most', 'ADV')),
#  (('disagreeable', 'X'), ('disagreeable', 'ADJ'))]

# %% [markdown]
# ### List down cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %%
# CASE 1 : Number is tagged by Vanilla Viterbi is Adverb, with modified it is correctly as Num
print("Before {}, After{}".format(Viterbi(['8.06']),Viterbi(['8.06'],backoff=[cardinal_X_tagger,english_morphological_tagger])))
print("Before {}, After{}".format(Viterbi(['1980s']),Viterbi(['1980s'],backoff=[cardinal_X_tagger,english_morphological_tagger])))
print("Before {}, After{}".format(Viterbi(['CERTIFICATES']),Viterbi(['CERTIFICATES'],backoff=[cardinal_X_tagger,english_morphological_tagger])))
print("Before {}, After{}".format(Viterbi(['parts-engineering']),Viterbi(['parts-engineering'],backoff=[cardinal_X_tagger,english_morphological_tagger])))
print("Before {}, After{}".format(Viterbi(['Consent']),Viterbi(['Consent'],backoff=[cardinal_X_tagger,english_morphological_tagger])))
print("Before {}, After{}".format(Viterbi(['100-megabytes']),Viterbi(['100-megabytes'],backoff=[cardinal_X_tagger,english_morphological_tagger])))
print("Before {}, After{}".format(Viterbi(['leveling']),Viterbi(['leveling'],backoff=[cardinal_X_tagger,english_morphological_tagger])))
# Out:
# Before [('8.06', 'ADV')], After[('8.06', 'NUM')]
# Before [('1980s', 'NUM')], After[('1980s', 'NUM')]
# Before [('CERTIFICATES', 'ADV')], After[('CERTIFICATES', 'NOUN')]
# Before [('parts-engineering', 'ADV')], After[('parts-engineering', 'ADJ')]
# Before [('Consent', 'ADV')], After[('Consent', 'NOUN')]
# Before [('100-megabytes', 'ADV')], After[('100-megabytes', 'ADJ')]
# Before [('leveling', 'ADV')], After[('leveling', 'VERB')]

# %% [markdown]
# ##### Reading Test File

# %%
# Readinig the Test File
with open('./Test_sentences.txt','r') as f:
    lines=f.readlines()
# joining lines to form a single string
test_string=reduce(lambda x,y: x+ ' '+y,lines)
test_string=test_string.replace('\n','') #removing extra new line characters
test_string=test_string.strip() #strip white spaces
# Generating word tokens from sentence
test_tokens=word_tokenize(test_string)
test_set=nltk.pos_tag(test_tokens)
test_set=list(map(tag_converted,test_set))
test_set_words=[v[0] for v in test_set]
# test_set

# %%
tagged_seq=Viterbi(test_set_words)
check = [i for i, j in zip(tagged_seq, test_set) if i == j] 
accuracy = len(check)/len(tagged_seq)
print(accuracy)
incorrect_tagged_cases = [j for i, j in enumerate(zip(tagged_seq, test_set)) if j[0]!=j[1]]

# %%
tagged_seq=Viterbi(test_set_words,backoff=[cardinal_tagger,english_morphological_tagger])
check = [i for i, j in zip(tagged_seq, test_set) if i == j] 
accuracy = len(check)/len(tagged_seq)
print(accuracy)
incorrect_tagged_cases = [j for i, j in enumerate(zip(tagged_seq, test_set)) if j[0]!=j[1]]

# %%
incorrect_tagged_cases

# %%
def tag_converted(x):
    tag=x[1]
    v=x[0]
    if x[1]=='NNP' or x[1]=='NNS' or x[1]=='NN' or x[1]=='NNPS':
        tag='NOUN'
    elif x[1]=='VB' or x[1]=='VBD' or x[1]=='VBG' or x[1]=='VBZ' or x[1]=='VBN' or x[1]=='VBP' or x[1]=='MD':
        tag='VERB'
    elif x[1]=='JJ' or x[1]=='JJS':
        tag='ADJ'
    elif x[1]=='DT' or x[1]=='WDT':
        tag='DET'
    elif x[1]=='CD':
        tag='NUM'
    elif x[1]=='RB':
        tag='ADV'
    elif x[1]=='PRP' or x[1]=='IN':
        tag='ADP'
    elif x[1]=='CC':
        tag='CONJ'
    elif x[1]=='PRP':
        tag='PRON'
    return (v,tag)

# %%
testing_set

# %%
nltk.help.upenn_tagset()

# %%
nltk.pos_tag(['that'])
